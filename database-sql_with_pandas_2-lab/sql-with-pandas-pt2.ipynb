# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Practice SQL with Pandas pt. 2
#
#
# ---
#
# We've learned about relational databases and the language most use to query them, SQL.
#
# In this lab we are going to gain more practice converting information to a SQL DB, querying the data and then analyzing it with Python.

# %%
# Necessary Libraries
import pandas as pd
import sqlite3
from pandas.io import sql

# %% [markdown]
# #### 1.  Read in the EuroMart CSV Data.
# - 'EuroMart-ListOfOrders.csv'
# - 'EuroMart-OrderBreakdown.csv'
# - 'EuroMart-SalesTargets.csv'

# %%
# Reading CSV to Dataframe
orders = pd.read_csv('./datasets/csv/EuroMart-ListOfOrders.csv', encoding = 'utf-8')
OBD =  pd.read_csv('./datasets/csv/EuroMart-OrderBreakdown.csv', encoding = 'utf-8')
sales_targets =  pd.read_csv('./datasets/csv/EuroMart-SalesTargets.csv', encoding = 'utf-8')

# %% [markdown]
# #### 2. Rename columns to remove any spaces.

# %%
# A: 
orders.columns =['Order_ID', 'Order_Date', 'Customer_Name', 'City', 'Country', 'Region',
       'Segment', 'Ship_Date', 'Ship_Mode', 'State']

# %%
orders.head()
# Out:
#           Order_ID Order_Date     Customer_Name        City         Country  \
# 0  BN-2011-7407039   1/1/2011        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313   1/3/2011    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300   1/4/2011  Devin Huddleston     Valence          France
# 3  BN-2011-2819714   1/4/2011       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423   1/5/2011      Daniel Burke  Echirolles          France
#
#     Region      Segment Ship_Date     Ship_Mode                 State
# 0    North  Home Office  1/5/2011  Economy Plus             Stockholm
# 1    North     Consumer  1/7/2011       Economy               England
# 2  Central     Consumer  1/8/2011       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate  1/9/2011       Economy               England
# 4  Central  Home Office  1/7/2011      Priority  Auvergne-Rhône-Alpes

# %%
OBD.columns
# Out:
# Index(['Order ID', 'Product Name', 'Discount', 'Sales', 'Profit', 'Quantity',
#        'Category', 'Sub-Category'],
#       dtype='object')

# %%
OBD.columns=['Order_ID', 'Product_Name', 'Discount', 'Sales', 'Profit', 'Quantity',
       'Category', 'Sub_Category']

# %%
sales_targets.columns
# Out:
# Index(['Month of Order Date', 'Category', 'Target'], dtype='object')

# %%
sales_targets.columns= ['Month_of_Order_Date', 'Category', 'Target']

# %% [markdown]
# #### 3. Remove dollar signs from sales and profit columns in the order breakdown dataframe.
#
# Convert the columns to float.

# %%
# A: 
OBD.head()
# Out:
#           Order_ID                           Product_Name  Discount    Sales  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5   $45.00
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0  $854.00
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0  $140.00
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5   $27.00
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5   $17.00
#
#     Profit  Quantity         Category Sub_Category
# 0  -$26.00         3  Office Supplies        Paper
# 1  $290.00         7        Furniture    Bookcases
# 2   $21.00         3  Office Supplies          Art
# 3  -$22.00         2  Office Supplies          Art
# 4   -$1.00         2  Office Supplies      Storage

# %%
OBD['Sales'] = OBD['Sales'].apply(lambda x: float(x.replace('$','').replace(',','')))
OBD['Profit'] = OBD['Profit'].apply(lambda x: float(x.replace('$','').replace(',','')))

# %% [markdown]
# #### 4. Create a SQL Database called 'EuroMart' and save the three dataframes as SQL tables.

# %%
# Establishing Local DB connection
db_connection = sqlite3.connect('./datasets/sql/EuroMart.db.sqlite')

# %%
# A: 
orders.to_sql(name = 'orders', con = db_connection, if_exists = 'replace', index = False)
OBD.to_sql(name = 'OBD', con = db_connection, if_exists = 'replace', index = False)
sales_targets.to_sql(name = 'sales_target', con = db_connection, if_exists = 'replace', index = False)

# %% [markdown]
# #### 5. How many orders has each Customer placed?

# %%
# A:
query = 'select customer_name from orders'

results = sql.read_sql(query, con = db_connection)

# %%
results['Customer_Name'].value_counts()
# Out:
# Jose Gambino           13
# Mark Washington        12
# Kayla Tearle           12
# Rachel Tyler           11
# Patricia Smith         11
# Georgina Garner        11
# Lilly Le Grand         11
# Aaron Bootman          11
# Maya Pamphlett         11
# Lori Miller            11
# Hayden Perkins         11
# Jessica Paramor        11
# Michael Myers          11
# Jason Roger            11
# Terence Welch          11
# Angie Massengill       10
# Philip Newsom          10
# Ngoc Orozco            10
# Peter Daly             10
# Robert Quick           10
# Michael Watkins        10
# Alexandra Macdonald    10
# Ashton Charles         10
# Elijah Sodeman         10
# Chelsea Bannister      10
# Owen Howell            10
# Elise Ali              10
# Kian Sykes             10
# Isaac David            10
# Jasmine Slater         10
#                        ..
# Grace Brown             1
# Elliot Owen             1
# Claire Dilke            1
# Tegan Savage            1
# Shannon Lane            1
# Louie Bryant            1
# Dakota Baynes           1
# Audry Smith             1
# Dustin Thomas           1
# Charles Rice            1
# Imogen Smithies         1
# Herbert Harrell         1
# Aaron Macrossan         1
# Anna Church             1
# Mason Porter            1
# Jay Collier             1
# Tyler Whitehead         1
# Max Baker               1
# Pearl Summers           1
# Bethany Powell          1
# Jack Maughan            1
# Patrick Atkinson        1
# Clifford Defreitas      1
# Stephanie Ewen          1
# Erin Wallis             1
# Alexandra Mahmood       1
# Hayden Weigel           1
# James Brown             1
# Jodie Garner            1
# Bella Handfield         1
# Name: Customer_Name, Length: 792, dtype: int64

# %% [markdown]
# > *If you're doubting your output check using Pandas*

# %% [markdown]
# #### 6. Create a Query to return a table of only geographic features from the List of Orders Table.

# %%
# A:
query = 'select City,Country, Region, State from orders'

results = sql.read_sql(query, con = db_connection)

results.head()
# Out:
#          City         Country   Region                 State
# 0   Stockholm          Sweden    North             Stockholm
# 1   Southport  United Kingdom    North               England
# 2     Valence          France  Central  Auvergne-Rhône-Alpes
# 3  Birmingham  United Kingdom    North               England
# 4  Echirolles          France  Central  Auvergne-Rhône-Alpes

# %% [markdown]
# #### 7. Create a Query to return a table with all of the orders that had a negative profit from the Order Breakdown Table.

# %%
# A:
query = 'select * from OBD where Profit < 0'

results = sql.read_sql(query, con = db_connection)

results.head()
# Out:
#           Order_ID                     Product_Name  Discount  Sales  Profit  \
# 0  BN-2011-7407039      Enermax Note Cards, Premium       0.5   45.0   -26.0
# 1  BN-2011-2819714       Boston Markers, Easy-Erase       0.5   27.0   -22.0
# 2  BN-2011-2819714      Eldon Folders, Single Width       0.5   17.0    -1.0
# 3  BN-2011-3248724     Ikea Classic Bookcase, Metal       0.6  987.0 -1012.0
# 4  BN-2011-3248724  Binney & Smith Sketch Pad, Blue       0.5  116.0   -56.0
#
#    Quantity         Category Sub_Category
# 0         3  Office Supplies        Paper
# 1         2  Office Supplies          Art
# 2         2  Office Supplies      Storage
# 3         6        Furniture    Bookcases
# 4         5  Office Supplies          Art

# %% [markdown]
# #### 8. Construct a query to return a table with the Customer Name and Product Name.
#
# > **Note:** This will require a join!

# %%
orders.head()
# Out:
#           Order_ID Order_Date     Customer_Name        City         Country  \
# 0  BN-2011-7407039   1/1/2011        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313   1/3/2011    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300   1/4/2011  Devin Huddleston     Valence          France
# 3  BN-2011-2819714   1/4/2011       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423   1/5/2011      Daniel Burke  Echirolles          France
#
#     Region      Segment Ship_Date     Ship_Mode                 State
# 0    North  Home Office  1/5/2011  Economy Plus             Stockholm
# 1    North     Consumer  1/7/2011       Economy               England
# 2  Central     Consumer  1/8/2011       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate  1/9/2011       Economy               England
# 4  Central  Home Office  1/7/2011      Priority  Auvergne-Rhône-Alpes

# %%
OBD.head()
# Out:
#           Order_ID                           Product_Name  Discount  Sales  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5   45.0
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0  854.0
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0  140.0
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5   27.0
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5   17.0
#
#    Profit  Quantity         Category Sub_Category
# 0   -26.0         3  Office Supplies        Paper
# 1   290.0         7        Furniture    Bookcases
# 2    21.0         3  Office Supplies          Art
# 3   -22.0         2  Office Supplies          Art
# 4    -1.0         2  Office Supplies      Storage

# %%
def Q(query, db=db_connection):
    return sql.read_sql(query, db)

# %%
# A:
# A:
Q('''
SELECT o.Customer_Name, OBD.Product_Name
FROM orders AS o
INNER JOIN OBD ON o.Order_ID=OBD.Order_ID ''')
# Out:
#             Customer_Name                                       Product_Name
# 0              Ruby Patel                        Enermax Note Cards, Premium
# 1          Summer Hayward                 Dania Corner Shelving, Traditional
# 2        Devin Huddleston              Binney & Smith Sketch Pad, Easy-Erase
# 3             Mary Parker                         Boston Markers, Easy-Erase
# 4             Mary Parker                        Eldon Folders, Single Width
# 5            Daniel Burke       Binney & Smith Pencil Sharpener, Water Color
# 6            Daniel Burke                        Sanford Canvas, Fluorescent
# 7      Fredrick Beveridge                  Accos Thumb Tacks, Assorted Sizes
# 8      Fredrick Beveridge                      Bush Floating Shelf Set, Pine
# 9      Fredrick Beveridge                          Smead Lockers, Industrial
# 10            Archer Hort                    Binney & Smith Sketch Pad, Blue
# 11            Archer Hort                       Ikea Classic Bookcase, Metal
# 12         Evie Flockhart                Ibico Hole Reinforcements, Recycled
# 13        Faith Greenwood                         Boston Canvas, Fluorescent
# 14        Faith Greenwood                          Smead Trays, Single Width
# 15         Summer Hayward          Bevis Training Table, with Bottom Storage
# 16         Summer Hayward           Novimex File Folder Labels, Alphabetical
# 17          Gracie Powell                        Binney & Smith Canvas, Blue
# 18          Gracie Powell              SAFCO Executive Leather Armchair, Red
# 19         Hershel Snyder                        Binney & Smith Canvas, Blue
# 20         Hershel Snyder                               Epson Printer, White
# 21         Hershel Snyder                             Ibico Index Tab, Clear
# 22         Hershel Snyder               Ikea Stackable Bookrack, Traditional
# 23          Julia Martell                           Hon Chairmat, Adjustable
# 24           Viola Watson                   Green Bar Note Cards, Multicolor
# 25           Julian Dobie            Green Bar Cards & Envelopes, Multicolor
# 26           Julian Dobie  Harbour Creations Legal Exhibit Labels, Laser ...
# 27           Julian Dobie                                Smead Lockers, Blue
# 28           Julian Dobie          Wilson Jones Hole Reinforcements, Durable
# 29              Rose Heap                          Sanford Pens, Fluorescent
# ...                   ...                                                ...
# 8017      Lauren Saunders                     Lesro Round Table, Rectangular
# 8018      Lauren Saunders            Motorola Signal Booster, with Caller ID
# 8019      Lauren Saunders                Xerox Cards & Envelopes, Multicolor
# 8020        Darcy Farnell                           Deflect-O Clock, Durable
# 8021        Darcy Farnell                             Epson Inkjet, Wireless
# 8022        Darcy Farnell                    Panasonic Card Printer, Durable
# 8023          Jay Collier                       Novimex Rocking Chair, Black
# 8024        Rachel Morton                              BIC Pens, Fluorescent
# 8025        Rachel Morton                         Sanford Highlighters, Blue
# 8026      Mark Washington                        Avery 3-Hole Punch, Economy
# 8027      Mark Washington                                   Sharp Ink, Laser
# 8028      Mark Washington                               Stanley Canvas, Blue
# 8029       Mary Saterfiel                         Fellowes Box, Single Width
# 8030    Alexis O'Flaherty                    Rubbermaid Door Stop, Erganomic
# 8031           Max Ludwig                   Office Star Chairmat, Adjustable
# 8032     Georgia Arundale                               Acco Binder, Economy
# 8033      Thomas Thompson                        Canon Fax and Copier, Laser
# 8034      Thomas Thompson                          Kleencut Ruler, Easy Grip
# 8035      Thomas Thompson                      Nokia Headset, with Caller ID
# 8036      Thomas Thompson                               Sanford Canvas, Blue
# 8037       Dennis Conaway                          Cuisinart Blender, Silver
# 8038          Evie Morton                       Fellowes Lockers, Wire Frame
# 8039         Eloise Sykes                          Kleencut Shears, Serrated
# 8040         Jose Gambino               Ikea Stackable Bookrack, Traditional
# 8041         Jose Gambino                          Motorola Audio Dock, VoIP
# 8042          Leon Barnes                    Fellowes Shelving, Single Width
# 8043  Rebecca Chamberlain                    Wilson Jones Index Tab, Economy
# 8044      Daniel Hamilton                      Avery Binder Covers, Recycled
# 8045      Daniel Hamilton                  BIC Pencil Sharpener, Fluorescent
# 8046      Daniel Hamilton                                StarTech Phone, Red
#
# [8047 rows x 2 columns]

# %% [markdown]
# #### 9.  How many orders for "Office Supplies" (Category) has Sweden made?
#
# > **Note:** from this point on you'll probably be combining SQL and Pandas, in that you would use SQL querys to gather the relevant information and use Pandas to analyze it.

# %%
# A:
sweden_os = Q('''
SELECT *
FROM orders AS o
INNER JOIN OBD ON o.Order_ID=OBD.Order_ID
WHERE OBD.Category="Office Supplies"
AND o.Country = "Sweden"''')

# %%
sweden_os.head()
# Out:
#           Order_ID Order_Date Customer_Name        City Country Region  \
# 0  BN-2011-7407039   1/1/2011    Ruby Patel   Stockholm  Sweden  North
# 1  BN-2011-2807470  1/13/2011     Rose Heap  Gothenburg  Sweden  North
# 2  BN-2011-7087921   2/3/2011    Max Ludwig     Uppsala  Sweden  North
# 3   BN-2011-827720   5/9/2011     Ewan Hyde   Stockholm  Sweden  North
# 4  BN-2011-8234232  5/10/2011  Erick Tanner   Stockholm  Sweden  North
#
#        Segment  Ship_Date     Ship_Mode            State         Order_ID  \
# 0  Home Office   1/5/2011  Economy Plus        Stockholm  BN-2011-7407039
# 1     Consumer  1/20/2011       Economy  Västra Götaland  BN-2011-2807470
# 2  Home Office   2/5/2011  Economy Plus          Uppsala  BN-2011-7087921
# 3     Consumer  5/14/2011       Economy        Stockholm   BN-2011-827720
# 4    Corporate  5/12/2011  Economy Plus        Stockholm  BN-2011-8234232
#
#                             Product_Name  Discount  Sales  Profit  Quantity  \
# 0            Enermax Note Cards, Premium       0.5   45.0   -26.0         3
# 1              Sanford Pens, Fluorescent       0.5   31.0   -14.0         5
# 2    Boston Pencil Sharpener, Easy-Erase       0.5   91.0   -62.0         6
# 3  Sanford Pencil Sharpener, Fluorescent       0.5   26.0    -8.0         2
# 4   Boston Pencil Sharpener, Water Color       0.5   44.0   -32.0         3
#
#           Category Sub_Category
# 0  Office Supplies        Paper
# 1  Office Supplies          Art
# 2  Office Supplies          Art
# 3  Office Supplies          Art
# 4  Office Supplies          Art

# %%
len(sweden_os)
# Out:
# 133

# %% [markdown]
# #### 10. What was the total sales for products that have been discounted?

# %%
# A:
discounted_sales = Q('''
SELECT *
FROM OBD
WHERE discount>0
''')

# %%
discounted_sales.head()
# Out:
#           Order_ID                   Product_Name  Discount  Sales  Profit  \
# 0  BN-2011-7407039    Enermax Note Cards, Premium       0.5   45.0   -26.0
# 1  BN-2011-2819714     Boston Markers, Easy-Erase       0.5   27.0   -22.0
# 2  BN-2011-2819714    Eldon Folders, Single Width       0.5   17.0    -1.0
# 3  AZ-2011-2918397  Bush Floating Shelf Set, Pine       0.1  155.0    36.0
# 4  AZ-2011-2918397      Smead Lockers, Industrial       0.1  716.0   143.0
#
#    Quantity         Category Sub_Category
# 0         3  Office Supplies        Paper
# 1         2  Office Supplies          Art
# 2         2  Office Supplies      Storage
# 3         1        Furniture    Bookcases
# 4         4  Office Supplies      Storage

# %%
discounted_sales['Sales'].sum()
# Out:
# 1115614.0

# %% [markdown]
# #### 11. What is the total quantity of objects sold for each country?

# %%
orders.head()
# Out:
#           Order_ID Order_Date     Customer_Name        City         Country  \
# 0  BN-2011-7407039   1/1/2011        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313   1/3/2011    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300   1/4/2011  Devin Huddleston     Valence          France
# 3  BN-2011-2819714   1/4/2011       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423   1/5/2011      Daniel Burke  Echirolles          France
#
#     Region      Segment Ship_Date     Ship_Mode                 State
# 0    North  Home Office  1/5/2011  Economy Plus             Stockholm
# 1    North     Consumer  1/7/2011       Economy               England
# 2  Central     Consumer  1/8/2011       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate  1/9/2011       Economy               England
# 4  Central  Home Office  1/7/2011      Priority  Auvergne-Rhône-Alpes

# %%
# A:
Q('''
SELECT o.country, SUM(OBD.Quantity)
FROM orders AS o
INNER JOIN OBD ON o.Order_ID=OBD.Order_ID
GROUP BY o.country''')
# Out:
#            Country  SUM(OBD.Quantity)
# 0          Austria                973
# 1          Belgium                532
# 2          Denmark                204
# 3          Finland                201
# 4           France               7329
# 5          Germany               6179
# 6          Ireland                392
# 7            Italy               3612
# 8      Netherlands               1526
# 9           Norway                261
# 10        Portugal                286
# 11           Spain               2881
# 12          Sweden                753
# 13     Switzerland                308
# 14  United Kingdom               4917

# %% [markdown]
# #### 12. In what Countries are profits lowest? (Report lowest 5-10)

# %%
# A:
Q('''
SELECT o.country, SUM(OBD.Profit)
FROM orders AS o
INNER JOIN OBD ON o.Order_ID=OBD.Order_ID
GROUP BY o.country
ORDER BY SUM(OBD.Profit) 
LIMIT 5''')
# Out:
#        Country  SUM(OBD.Profit)
# 0  Netherlands         -37188.0
# 1       Sweden         -17524.0
# 2     Portugal          -8704.0
# 3      Ireland          -6886.0
# 4      Denmark          -3608.0

# %% [markdown]
# #### 13. What Counties have the best and worst Sales to Profit Ratios?
# (Total Sales divided by Total Profits.)
# Essentially this is saying for every dollar of product sold, how much is profit.

# %%
# A:
df = Q('''
SELECT o.country, OBD.Profit, OBD.Sales
FROM orders AS o
INNER JOIN OBD ON o.Order_ID=OBD.Order_ID
''')

# %%
new_df = df.groupby('Country').sum()
new_df.head()
# Out:
#           Profit     Sales
# Country
# Austria  21332.0   79382.0
# Belgium   9912.0   42320.0
# Denmark  -3608.0    7763.0
# Finland   3908.0   20702.0
# France   70067.0  609683.0

# %%
new_df['ratio'] = new_df['Profit']/new_df['Sales']

# %%
new_df.sort_values('ratio')
# Out:
#                  Profit     Sales     ratio
# Country
# Portugal        -8704.0   15106.0 -0.576195
# Sweden         -17524.0   30490.0 -0.574746
# Netherlands    -37188.0   70313.0 -0.528892
# Denmark         -3608.0    7763.0 -0.464769
# Ireland         -6886.0   15998.0 -0.430429
# Italy           15802.0  252742.0  0.062522
# France          70067.0  609683.0  0.114924
# Germany         86279.0  488681.0  0.176555
# Spain           47067.0  249402.0  0.188719
# Finland          3908.0   20702.0  0.188774
# United Kingdom  90382.0  420497.0  0.214941
# Belgium          9912.0   42320.0  0.234216
# Norway           5167.0   20529.0  0.251693
# Austria         21332.0   79382.0  0.268726
# Switzerland      7234.0   24874.0  0.290826

# %% [markdown]
# #### 14. What Shipping method is most common for 'Bookcases' (Sub Category)?

# %%
# A:

df = Q('''
SELECT o.Ship_mode, OBD.Sub_Category
FROM orders AS o
INNER JOIN OBD ON o.Order_ID=OBD.Order_ID
WHERE OBD.Sub_Category ="Bookcases"
''')

# %%
df.head()
# Out:
#   Ship_Mode Sub_Category
# 0   Economy    Bookcases
# 1  Priority    Bookcases
# 2   Economy    Bookcases
# 3   Economy    Bookcases
# 4   Economy    Bookcases

# %%
df['Ship_Mode'].value_counts()
# Out:
# Economy         234
# Economy Plus     76
# Priority         59
# Immediate        22
# Name: Ship_Mode, dtype: int64

# %% [markdown]
# #### 15 .What city in the Orders table generated the highest net sales?  (List all the cities and countries in descending order by net sales.)

# %%
# A:

df = Q('''
SELECT o.city, o.country, OBD.Sales, OBD.profit
FROM orders AS o
INNER JOIN OBD ON o.Order_ID=OBD.Order_ID''')

# %%
df.head()
# Out:
#          City         Country  Sales  Profit
# 0   Stockholm          Sweden   45.0   -26.0
# 1   Southport  United Kingdom  854.0   290.0
# 2     Valence          France  140.0    21.0
# 3  Birmingham  United Kingdom   17.0    -1.0
# 4  Birmingham  United Kingdom   27.0   -22.0

# %%
new_df = df.groupby(['City','Country']).sum()

# %%
new_df.head()
# Out:
#                            Sales  Profit
# City      Country
# Aachen    Germany         1419.0   372.0
# Aalen     Germany          980.0   283.0
# Aalst     Belgium          388.0   152.0
# Abbeville France           218.0    10.0
# Aberdeen  United Kingdom  1547.0   525.0

# %%
new_df['net_sales']=new_df['Sales']-new_df['Profit']
new_df.head()
# Out:
#                            Sales  Profit  net_sales
# City      Country
# Aachen    Germany         1419.0   372.0     1047.0
# Aalen     Germany          980.0   283.0      697.0
# Aalst     Belgium          388.0   152.0      236.0
# Abbeville France           218.0    10.0      208.0
# Aberdeen  United Kingdom  1547.0   525.0     1022.0

# %%
new_df.sort_values('net_sales')
# Out:
#                                          Sales   Profit  net_sales
# City                   Country
# Osny                   France              5.0      2.0        3.0
# Aix-les-Bains          France             10.0      4.0        6.0
# Sète                   France             14.0      7.0        7.0
# Sorgues                France             14.0      3.0       11.0
# Friedberg              Germany            18.0      6.0       12.0
# Cluses                 France             28.0     14.0       14.0
# Ragusa                 Italy              22.0      7.0       15.0
# Viroflay               France             26.0     11.0       15.0
# Givors                 France             26.0     10.0       16.0
# Millau                 France             21.0      5.0       16.0
# Illkirch-Graffenstaden France             24.0      8.0       16.0
# Cestas                 France             23.0      6.0       17.0
# Andria                 Italy              26.0      9.0       17.0
# Massa                  Italy              26.0      8.0       18.0
# Falconara Marittima    Italy              26.0      7.0       19.0
# La Crau                France             31.0     11.0       20.0
# Ponteareas             Spain              37.0     17.0       20.0
# Morley                 United Kingdom     27.0      6.0       21.0
# Estepona               Spain              34.0     12.0       22.0
# Vigevano               Italy              28.0      6.0       22.0
# Torremolinos           Spain              33.0     10.0       23.0
# Taunton                United Kingdom     39.0     16.0       23.0
# Cinisello Balsamo      Italy              45.0     22.0       23.0
# Montigny-le-Bretonneux France             36.0     12.0       24.0
# Le Pré-Saint-Gervais   France             53.0     26.0       27.0
# Lomme                  France             39.0     11.0       28.0
# Manresa                Spain              38.0      9.0       29.0
# Peer                   Belgium            44.0     14.0       30.0
# Gosport                United Kingdom     41.0     11.0       30.0
# Manfredonia            Italy              25.0     -5.0       30.0
# ...                                        ...      ...        ...
# Amsterdam              Netherlands      6978.0  -3421.0    10399.0
# Cologne                Germany         13301.0   2891.0    10410.0
# The Hague              Netherlands      7370.0  -3121.0    10491.0
# Lisbon                 Portugal         6217.0  -4278.0    10495.0
# Valladolid             Spain           10938.0     58.0    10880.0
# Bremen                 Germany         15342.0   3795.0    11547.0
# Frankfurt              Germany         14640.0   2982.0    11658.0
# Bochum                 Germany         15144.0   3295.0    11849.0
# Valencia               Spain           14958.0   3055.0    11903.0
# Dortmund               Germany         12724.0    526.0    12198.0
# Naples                 Italy           11388.0  -1140.0    12528.0
# Edinburgh              United Kingdom  18016.0   5173.0    12843.0
# Hanover                Germany          6865.0  -6130.0    12995.0
# Lille                  France          14102.0    827.0    13275.0
# Birmingham             United Kingdom   9559.0  -4652.0    14211.0
# Munich                 Germany         18429.0   3463.0    14966.0
# Dublin                 Ireland         11071.0  -4681.0    15752.0
# Hamburg                Germany         23574.0   5858.0    17716.0
# Turin                  Italy           19829.0   1937.0    17892.0
# Milan                  Italy           18837.0    233.0    18604.0
# Marseille              France          21677.0   2889.0    18788.0
# Toulouse               France          11565.0  -9675.0    21240.0
# Barcelona              Spain           27405.0   2246.0    25159.0
# Rome                   Italy           28330.0    191.0    28139.0
# Stockholm              Sweden          17498.0 -11633.0    29131.0
# Madrid                 Spain           44981.0  11129.0    33852.0
# Paris                  France          42245.0   6680.0    35565.0
# Vienna                 Austria         51844.0  13207.0    38637.0
# Berlin                 Germany         52555.0   5942.0    46613.0
# London                 United Kingdom  69230.0  13931.0    55299.0
#
# [999 rows x 3 columns]

# %% [markdown]
# #### BONUS: Create a Column called 'Shipping Delay' on the 'orders' table, which is the difference in days between 'Order Date' and 'Ship Date'.

# %%
# A:

# %%
# A:

# %% [markdown]
# #### BONUS: Update your Orders table in your Sqlite DB to include the 'Shipping Delay' feature.

# %%
# A:

# %% [markdown]
# #### BONUS: Which Product Category has the highest average 'Shipping Delay'?

# %%
# A:

# %% [markdown]
# ### Challenge problem:
# **In what months and Categories were Sales Targets Exceeded?**
#
# ---
#
# This may require a considerable amount of data processing.

# %%
# A:
